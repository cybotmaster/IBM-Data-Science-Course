# %% [markdown]
# # **My Jupyter Notebook on IBM Watson Studio**

# %% [markdown]
# **I am Wei Hao Loh,**
#
# **currently a student :)**

# %% [markdown]
# *I am interested in data science because I realised that there is a need for data scientists around the world. In the midst of this pandemic, most of us have to work/study from home. I would like to take this opportunity to learn data science and be part of this bandwagon.*

# %% [markdown]
# ### **The objective of the following code is to get tables, such as those at https://tradingeconomics.com/stocks, conduct a web scraping and printing out the results.**

# %%
import pandas as pd

results = pd.read_html('https://tradingeconomics.com/stocks')

for table in results:

    print(table)
# Out:
#    Unnamed: 0 United States     Price  Unnamed: 3     Day  Weekly Monthly  \
# 0         NaN     Dow Jones  25025.00      720.60  -2.80%  -3.27%  -2.05%
# 1         NaN       S&P 500   3016.00       67.76  -2.20%  -2.64%  -0.66%
# 2         NaN    NASDAQ 100   9920.00      181.83  -1.80%  -0.89%   5.06%
# 3         NaN       S&P VIX     35.72        3.50   3.50%   0.60%   8.10%
#
#    Yearly    Date  Unnamed: 9
# 0  -5.66%  Jun/26         NaN
# 1   3.11%  Jun/26         NaN
# 2  29.55%  Jun/26         NaN
# 3  19.90%  Jun/26         NaN
#     Unnamed: 0               Europe      Price  Unnamed: 3     Day  Weekly  \
# 0          NaN             FTSE 100    6144.00        3.14  -0.05%  -2.36%
# 1          NaN                  DAX   12058.00      119.43  -0.98%  -2.21%
# 2          NaN               CAC 40    4896.00       22.49  -0.46%  -1.67%
# 3          NaN             FTSE MIB   19147.00       82.75  -0.43%  -2.41%
# ...

# %% [markdown]
# **For the 3 requirements:**
#
# *Bullets*
#  - This
#  - is
#  - a
#  - column
#  - of
#  - words
#
# *Strikethrough*
#
# Am I enjoying this course so far?
# - Yes
# - ~~No~~
#
# *Images*
#
# Using this programming language:
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/f/f8/Python_logo_and_wordmark.svg/500px-Python_logo_and_wordmark.svg.png" alt="Alt text" title="Title text" />
#
#
# With a notebook powered by:
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/3/38/Jupyter_logo.svg/250px-Jupyter_logo.svg.png" alt="Alt text" title="Title text" />
